# %%
import requests
from bs4 import BeautifulSoup
from csv import writer
import pandas as pd
import time
import csv
from tkinter import *
import random

# %%
#WCZYTYWANIE DANYCH DO PROGRAMU

df_Tenses = pd.read_csv(r'C:\Users\Jakub\Hiszpanski program\Lista_Czasow.csv',index_col=[0])
df_Verbs = pd.read_csv(r'C:\Users\Jakub\Hiszpanski program\Lista_slow.csv',index_col=[0])
df_Gerundio = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Gerundio.csv',index_col=[0])
df_Participio = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Participio.csv',index_col=[0])
df_Indicativo_Presente = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Indicativo_Presente.csv',index_col=[0])
df_Indicativo_Preterito_Imperfecto = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Indicativo_Preterito_Imperfecto.csv',index_col=[0])
df_Indicativo_Preterito_Perfecto_Simple = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Indicativo_Preterito_Perfecto_Simple.csv',index_col=[0])
df_Indicativo_Futuro_Simple = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Indicativo_Futuro_Simple.csv',index_col=[0])
df_Condicional_Simple = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Condicional_Simple.csv',index_col=[0])
df_Subjuntivo_Presente = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Subjuntivo_Presente.csv',index_col=[0])
df_Subjuntivo_Futuro_Simple = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Subjuntivo_Futuro_Simple.csv',index_col=[0])
df_Preterito_Imperfecto = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Preterito_Imperfecto.csv',index_col=[0])
df_Imperativo = pd.read_csv( r'C:\Users\Jakub\Hiszpanski program\Odmiany\Baza_Imperativo.csv',index_col=[0])

# %%
####Funkcje

#wypelnianie slowkami

def sprawdz():

    
    if tensevar.get() == 'Participio':
        verb = df_Participio['Forma'][indexvar.get()]
        conj7.set(verb)
        entry_misc.config(textvariable=conj7)
        
    elif tensevar.get() == 'Gerundio':
        verb = df_Gerundio['Forma'][indexvar.get()]
        conj7.set(verb)
        entry_misc.config(textvariable=conj7)
        
    elif tensevar.get() == 'Imperativo':
        conj2.set(df_Imperativo['tu'][indexvar.get()])
        conj3.set(df_Imperativo['usted'][indexvar.get()])
        conj5.set(df_Imperativo['vosotros'][indexvar.get()])
        conj6.set(df_Imperativo['ustedes'][indexvar.get()])
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)
        
    elif tensevar.get() == 'Indicativo Presente':
        conj1.set(df_Indicativo_Presente['yo'][indexvar.get()])
        conj2.set(df_Indicativo_Presente['tu'][indexvar.get()])
        conj3.set(df_Indicativo_Presente['el/ella'][indexvar.get()])
        conj4.set(df_Indicativo_Presente['nosotros'][indexvar.get()])
        conj5.set(df_Indicativo_Presente['vosotros'][indexvar.get()])
        conj6.set(df_Indicativo_Presente['ellos/ellas'][indexvar.get()])

        entry_1oslpoj.config(textvariable=conj1)
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_1oslmn.config(textvariable=conj4)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)        
        
    elif tensevar.get() == 'Indicativo Preterito Imperfecto':
        conj1.set(df_Indicativo_Preterito_Imperfecto['yo'][indexvar.get()])
        conj2.set(df_Indicativo_Preterito_Imperfecto['tu'][indexvar.get()])
        conj3.set(df_Indicativo_Preterito_Imperfecto['el/ella'][indexvar.get()])
        conj4.set(df_Indicativo_Preterito_Imperfecto['nosotros'][indexvar.get()])
        conj5.set(df_Indicativo_Preterito_Imperfecto['vosotros'][indexvar.get()])
        conj6.set(df_Indicativo_Preterito_Imperfecto['ellos/ellas'][indexvar.get()])

        entry_1oslpoj.config(textvariable=conj1)
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_1oslmn.config(textvariable=conj4)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)        
        
    elif tensevar.get() == 'Indicativo Preterito Perfecto Simple':
        conj1.set(df_Indicativo_Preterito_Perfecto_Simple['yo'][indexvar.get()])
        conj2.set(df_Indicativo_Preterito_Perfecto_Simple['tu'][indexvar.get()])
        conj3.set(df_Indicativo_Preterito_Perfecto_Simple['el/ella'][indexvar.get()])
        conj4.set(df_Indicativo_Preterito_Perfecto_Simple['nosotros'][indexvar.get()])
        conj5.set(df_Indicativo_Preterito_Perfecto_Simple['vosotros'][indexvar.get()])
        conj6.set(df_Indicativo_Preterito_Perfecto_Simple['ellos/ellas'][indexvar.get()])

        entry_1oslpoj.config(textvariable=conj1)
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_1oslmn.config(textvariable=conj4)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)        
        
    elif tensevar.get() == 'Indicativo Futuro Simple':
        conj1.set(df_Indicativo_Futuro_Simple['yo'][indexvar.get()])
        conj2.set(df_Indicativo_Futuro_Simple['tu'][indexvar.get()])
        conj3.set(df_Indicativo_Futuro_Simple['el/ella'][indexvar.get()])
        conj4.set(df_Indicativo_Futuro_Simple['nosotros'][indexvar.get()])
        conj5.set(df_Indicativo_Futuro_Simple['vosotros'][indexvar.get()])
        conj6.set(df_Indicativo_Futuro_Simple['ellos/ellas'][indexvar.get()])

        entry_1oslpoj.config(textvariable=conj1)
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_1oslmn.config(textvariable=conj4)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)        
        
    elif tensevar.get() == 'Condicional Simple':
        conj1.set(df_Condicional_Simple['yo'][indexvar.get()])
        conj2.set(df_Condicional_Simple['tu'][indexvar.get()])
        conj3.set(df_Condicional_Simple['el/ella'][indexvar.get()])
        conj4.set(df_Condicional_Simple['nosotros'][indexvar.get()])
        conj5.set(df_Condicional_Simple['vosotros'][indexvar.get()])
        conj6.set(df_Condicional_Simple['ellos/ellas'][indexvar.get()])

        entry_1oslpoj.config(textvariable=conj1)
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_1oslmn.config(textvariable=conj4)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)        
        
    elif tensevar.get() == 'Subjuntivo Presente':
        
        conj1.set(df_Subjuntivo_Presente['yo'][indexvar.get()])
        conj2.set(df_Subjuntivo_Presente['tu'][indexvar.get()])
        conj3.set(df_Subjuntivo_Presente['el/ella'][indexvar.get()])
        conj4.set(df_Subjuntivo_Presente['nosotros'][indexvar.get()])
        conj5.set(df_Subjuntivo_Presente['vosotros'][indexvar.get()])
        conj6.set(df_Subjuntivo_Presente['ellos/ellas'][indexvar.get()])

        entry_1oslpoj.config(textvariable=conj1)
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_1oslmn.config(textvariable=conj4)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)        
        
    elif tensevar.get() == 'Subjuntivo Futuro Simple':
        
        conj1.set(df_Subjuntivo_Futuro_Simple['yo'][indexvar.get()])
        conj2.set(df_Subjuntivo_Futuro_Simple['tu'][indexvar.get()])
        conj3.set(df_Subjuntivo_Futuro_Simple['el/ella'][indexvar.get()])
        conj4.set(df_Subjuntivo_Futuro_Simple['nosotros'][indexvar.get()])
        conj5.set(df_Subjuntivo_Futuro_Simple['vosotros'][indexvar.get()])
        conj6.set(df_Subjuntivo_Futuro_Simple['ellos/ellas'][indexvar.get()])
        
        entry_1oslpoj.config(textvariable=conj1)
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_1oslmn.config(textvariable=conj4)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)
        
    elif tensevar.get() == 'Preterito Imperfecto':
        
        conj1.set(df_Preterito_Imperfecto['yo'][indexvar.get()])
        conj2.set(df_Preterito_Imperfecto['tu'][indexvar.get()])
        conj3.set(df_Preterito_Imperfecto['el/ella'][indexvar.get()])
        conj4.set(df_Preterito_Imperfecto['nosotros'][indexvar.get()])
        conj5.set(df_Preterito_Imperfecto['vosotros'][indexvar.get()])
        conj6.set(df_Preterito_Imperfecto['ellos/ellas'][indexvar.get()])

        entry_1oslpoj.config(textvariable=conj1)
        entry_2oslpoj.config(textvariable=conj2)
        entry_3oslpoj.config(textvariable=conj3)
        entry_1oslmn.config(textvariable=conj4)
        entry_2oslmn.config(textvariable=conj5)
        entry_3oslmn.config(textvariable=conj6)  
        
    return()

#######Funkcja konwersji stringow na listy
def Convert(string):
    string1 = string.replace("(", "")
    string2 = string1.replace(")", "")
    string3 = string2.replace("'","")
    li = list(string3.split(", "))

    if len(li) == 1:
        li[0].replace(", ","")
#     for i in range(len(li)):
#         li[i] = int(li[i])
    return(li)


def losowanie():
    ###czasu
#     tense_choice = random.choice(range(len(df_Tenses)))
#     tense = df_Tenses['Czasy'][tense_choice]
    
#     x = Convert(ListVar.get())
#     print(random.choice(x))

    tensechoice = Convert(ListVar.get())
    if tensechoice[0] == "":
        tense = 'Nie wybrano listy czasów'
    elif tensechoice != "":
        tense = random.choice(Convert(ListVar.get()))    
    
    ###czasownika
    #czasownik
    verb_choice = random.choice(df_Verbs['Slowo'])
    a = int(df_Verbs[df_Verbs['Slowo']==verb_choice].index.values)
    
    #tlumaczenie
    translated_verb = df_Verbs['Tlumaczenie'][a]
    out = [verb_choice,translated_verb,tense,a]
    return(out)    
    
    
# def konwertujliste():
#     x = Convert(ListVar.get())
#     print(x)
    
def losuj():
        
    entry_1oslpoj.config(state='normal',fg = 'black')
    entry_1oslpoj.delete(0, "end")
    entry_2oslpoj.config(state='normal',fg = 'black')
    entry_2oslpoj.delete(0, "end")    
    entry_3oslpoj.config(state='normal',fg = 'black')
    entry_3oslpoj.delete(0, "end")    
    entry_1oslmn.config(state='normal',fg = 'black')
    entry_1oslmn.delete(0, "end")    
    entry_2oslmn.config(state='normal',fg = 'black')
    entry_2oslmn.delete(0, "end")    
    entry_3oslmn.config(state='normal',fg = 'black')
    entry_3oslmn.delete(0, "end")    
    entry_misc.config(state='normal',fg = 'black') 
    entry_misc.delete(0, "end")    


    los = losowanie()
    verbvar.set(los[0])
    translatevar.set(los[1])
    tensevar.set(los[2])
    indexvar.set(los[3])
    
#     print(verbvar.get()[-2:])
#     print(tensevar.get())
    
    LabelCzasowniklos.config(textvariable=verbvar)
    LabelCzasownikTlumaczenielos.config(textvariable=translatevar)
    LabelCzaslos.config(textvariable = tensevar)
    if tensevar.get() == 'Nie wybrano listy czasów':
        LabelCzaslos.config(fg='red')
        entry_1oslpoj.config(state='disabled',textvariable='')
        entry_2oslpoj.config(state='disabled')
        entry_3oslpoj.config(state='disabled')
        entry_1oslmn.config(state='disabled')
        entry_2oslmn.config(state='disabled')
        entry_3oslmn.config(state='disabled')
        entry_misc.config(state='disabled')
    elif tensevar.get() != 'Nie wybrano listy czasów':
        LabelCzaslos.config(fg='black')
        if tensevar.get() == "Gerundio" or tensevar.get() == "Participio":
            entry_1oslpoj.config(state='disabled',textvariable='')
            entry_2oslpoj.config(state='disabled')
            entry_3oslpoj.config(state='disabled')
            entry_1oslmn.config(state='disabled')
            entry_2oslmn.config(state='disabled')
            entry_3oslmn.config(state='disabled')
            entry_misc.config(state='normal')
        elif tensevar.get() == 'Imperativo':
            entry_1oslpoj.config(state='disabled')        
            entry_2oslpoj.config(state='normal')
            entry_3oslpoj.config(state='normal')
            entry_1oslmn.config(state='disabled')    
            entry_2oslmn.config(state='normal')
            entry_3oslmn.config(state='normal')    
            entry_misc.config(state='disabled')
        else:
            entry_1oslpoj.config(state='normal')
            entry_2oslpoj.config(state='normal')
            entry_3oslpoj.config(state='normal')
            entry_1oslmn.config(state='normal')
            entry_2oslmn.config(state='normal')
            entry_3oslmn.config(state='normal')
            entry_misc.config(state='disabled')
            
            
def verifyo1():
    
    if tensevar.get() == 'Indicativo Presente':
        if entry_1oslpoj.get() == df_Indicativo_Presente['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='green')
        elif entry_1oslpoj.get() != df_Indicativo_Presente['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='red')
    elif tensevar.get() == 'Indicativo Preterito Imperfecto':
        if entry_1oslpoj.get() == df_Preterito_Imperfecto['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='green')
        elif entry_1oslpoj.get() != df_Preterito_Imperfecto['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='red')    
    elif tensevar.get() == 'Indicativo Preterito Perfecto Simple':
        if entry_1oslpoj.get() == df_Indicativo_Preterito_Perfecto_Simple['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='green')
        elif entry_1oslpoj.get() != df_Indicativo_Preterito_Perfecto_Simple['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='red') 
    elif tensevar.get() == 'Indicativo Futuro Simple':
        if entry_1oslpoj.get() == df_Indicativo_Futuro_Simple['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='green')
        elif entry_1oslpoj.get() != df_Indicativo_Futuro_Simple['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='red') 
    elif tensevar.get() == 'Condicional Simple':
        if entry_1oslpoj.get() == df_Condicional_Simple['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='green')
        elif entry_1oslpoj.get() != df_Condicional_Simple['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Presente':
        if entry_1oslpoj.get() == df_Subjuntivo_Presente['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='green')
        elif entry_1oslpoj.get() != df_Subjuntivo_Presente['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Futuro Simple':
        if entry_1oslpoj.get() == df_Subjuntivo_Futuro_Simple['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='green')
        elif entry_1oslpoj.get() != df_Subjuntivo_Futuro_Simple['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='red') 
    elif tensevar.get() == 'Preterito Imperfecto':
        if entry_1oslpoj.get() == df_Preterito_Imperfecto['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='green')
        elif entry_1oslpoj.get() != df_Preterito_Imperfecto['yo'][indexvar.get()]:
            entry_1oslpoj.config(fg='red') 

def verifyo2():
    
    if tensevar.get() == 'Indicativo Presente':
        if entry_2oslpoj.get() == df_Indicativo_Presente['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Indicativo_Presente['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red')
    elif tensevar.get() == 'Indicativo Preterito Imperfecto':
        if entry_2oslpoj.get() == df_Preterito_Imperfecto['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Preterito_Imperfecto['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red')    
    elif tensevar.get() == 'Indicativo Preterito Perfecto Simple':
        if entry_2oslpoj.get() == df_Indicativo_Preterito_Perfecto_Simple['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Indicativo_Preterito_Perfecto_Simple['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red') 
    elif tensevar.get() == 'Indicativo Futuro Simple':
        if entry_2oslpoj.get() == df_Indicativo_Futuro_Simple['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Indicativo_Futuro_Simple['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red') 
    elif tensevar.get() == 'Condicional Simple':
        if entry_2oslpoj.get() == df_Condicional_Simple['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Condicional_Simple['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Presente':
        if entry_2oslpoj.get() == df_Subjuntivo_Presente['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Subjuntivo_Presente['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Futuro Simple':
        if entry_2oslpoj.get() == df_Subjuntivo_Futuro_Simple['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Subjuntivo_Futuro_Simple['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red') 
    elif tensevar.get() == 'Preterito Imperfecto':
        if entry_2oslpoj.get() == df_Preterito_Imperfecto['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Preterito_Imperfecto['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red') 
            
    elif tensevar.get() == 'Imperativo':
        if entry_2oslpoj.get() == df_Imperativo['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='green')
        elif entry_2oslpoj.get() != df_Imperativo['tu'][indexvar.get()]:
            entry_2oslpoj.config(fg='red')             
            
def verifyo3():
    
    if tensevar.get() == 'Indicativo Presente':
        if entry_3oslpoj.get() == df_Indicativo_Presente['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Indicativo_Presente['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='red')
    elif tensevar.get() == 'Indicativo Preterito Imperfecto':
        if entry_3oslpoj.get() == df_Preterito_Imperfecto['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Preterito_Imperfecto['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='red')    
    elif tensevar.get() == 'Indicativo Preterito Perfecto Simple':
        if entry_3oslpoj.get() == df_Indicativo_Preterito_Perfecto_Simple['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Indicativo_Preterito_Perfecto_Simple['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='red') 
    elif tensevar.get() == 'Indicativo Futuro Simple':
        if entry_3oslpoj.get() == df_Indicativo_Futuro_Simple['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Indicativo_Futuro_Simple['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='red') 
    elif tensevar.get() == 'Condicional Simple':
        if entry_3oslpoj.get() == df_Condicional_Simple['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Condicional_Simple['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Presente':
        if entry_3oslpoj.get() == df_Subjuntivo_Presente['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Subjuntivo_Presente['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Futuro Simple':
        if entry_3oslpoj.get() == df_Subjuntivo_Futuro_Simple['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Subjuntivo_Futuro_Simple['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='red') 
    elif tensevar.get() == 'Preterito Imperfecto':
        if entry_3oslpoj.get() == df_Preterito_Imperfecto['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Preterito_Imperfecto['el/ella'][indexvar.get()]:
            entry_3oslpoj.config(fg='red')
            
    elif tensevar.get() == 'Imperativo':
        if entry_3oslpoj.get() == df_Imperativo['usted'][indexvar.get()]:
            entry_3oslpoj.config(fg='green')
        elif entry_3oslpoj.get() != df_Imperativo['usted'][indexvar.get()]:
            entry_3oslpoj.config(fg='red')  
            
def verifyo4():
    
    if tensevar.get() == 'Indicativo Presente':
        if entry_1oslmn.get() == df_Indicativo_Presente['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='green')
        elif entry_1oslmn.get() != df_Indicativo_Presente['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='red')
    elif tensevar.get() == 'Indicativo Preterito Imperfecto':
        if entry_1oslmn.get() == df_Preterito_Imperfecto['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='green')
        elif entry_1oslmn.get() != df_Preterito_Imperfecto['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='red')    
    elif tensevar.get() == 'Indicativo Preterito Perfecto Simple':
        if entry_1oslmn.get() == df_Indicativo_Preterito_Perfecto_Simple['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='green')
        elif entry_1oslmn.get() != df_Indicativo_Preterito_Perfecto_Simple['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='red') 
    elif tensevar.get() == 'Indicativo Futuro Simple':
        if entry_1oslmn.get() == df_Indicativo_Futuro_Simple['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='green')
        elif entry_1oslmn.get() != df_Indicativo_Futuro_Simple['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='red') 
    elif tensevar.get() == 'Condicional Simple':
        if entry_1oslmn.get() == df_Condicional_Simple['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='green')
        elif entry_1oslmn.get() != df_Condicional_Simple['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Presente':
        if entry_1oslmn.get() == df_Subjuntivo_Presente['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='green')
        elif entry_1oslmn.get() != df_Subjuntivo_Presente['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Futuro Simple':
        if entry_1oslmn.get() == df_Subjuntivo_Futuro_Simple['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='green')
        elif entry_1oslmn.get() != df_Subjuntivo_Futuro_Simple['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='red') 
    elif tensevar.get() == 'Preterito Imperfecto':
        if entry_1oslmn.get() == df_Preterito_Imperfecto['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='green')
        elif entry_1oslmn.get() != df_Preterito_Imperfecto['nosotros'][indexvar.get()]:
            entry_1oslmn.config(fg='red') 
            
def verifyo5():
    
    if tensevar.get() == 'Indicativo Presente':
        if entry_2oslmn.get() == df_Indicativo_Presente['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Indicativo_Presente['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red')
    elif tensevar.get() == 'Indicativo Preterito Imperfecto':
        if entry_2oslmn.get() == df_Preterito_Imperfecto['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Preterito_Imperfecto['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red')    
    elif tensevar.get() == 'Indicativo Preterito Perfecto Simple':
        if entry_2oslmn.get() == df_Indicativo_Preterito_Perfecto_Simple['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Indicativo_Preterito_Perfecto_Simple['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red') 
    elif tensevar.get() == 'Indicativo Futuro Simple':
        if entry_2oslmn.get() == df_Indicativo_Futuro_Simple['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Indicativo_Futuro_Simple['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red') 
    elif tensevar.get() == 'Condicional Simple':
        if entry_2oslmn.get() == df_Condicional_Simple['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Condicional_Simple['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Presente':
        if entry_2oslmn.get() == df_Subjuntivo_Presente['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Subjuntivo_Presente['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Futuro Simple':
        if entry_2oslmn.get() == df_Subjuntivo_Futuro_Simple['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Subjuntivo_Futuro_Simple['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red') 
    elif tensevar.get() == 'Preterito Imperfecto':
        if entry_2oslmn.get() == df_Preterito_Imperfecto['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Preterito_Imperfecto['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red') 
            
    elif tensevar.get() == 'Imperativo':
        if entry_2oslmn.get() == df_Imperativo['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='green')
        elif entry_2oslmn.get() != df_Imperativo['vosotros'][indexvar.get()]:
            entry_2oslmn.config(fg='red')  

def verifyo6():
    
    if tensevar.get() == 'Indicativo Presente':
        if entry_3oslmn.get() == df_Indicativo_Presente['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Indicativo_Presente['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='red')
    elif tensevar.get() == 'Indicativo Preterito Imperfecto':
        if entry_3oslmn.get() == df_Preterito_Imperfecto['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Preterito_Imperfecto['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='red')    
    elif tensevar.get() == 'Indicativo Preterito Perfecto Simple':
        if entry_3oslmn.get() == df_Indicativo_Preterito_Perfecto_Simple['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Indicativo_Preterito_Perfecto_Simple['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='red') 
    elif tensevar.get() == 'Indicativo Futuro Simple':
        if entry_3oslmn.get() == df_Indicativo_Futuro_Simple['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Indicativo_Futuro_Simple['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='red') 
    elif tensevar.get() == 'Condicional Simple':
        if entry_3oslmn.get() == df_Condicional_Simple['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Condicional_Simple['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Presente':
        if entry_3oslmn.get() == df_Subjuntivo_Presente['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Subjuntivo_Presente['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='red') 
    elif tensevar.get() == 'Subjuntivo Futuro Simple':
        if entry_3oslmn.get() == df_Subjuntivo_Futuro_Simple['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Subjuntivo_Futuro_Simple['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='red') 
    elif tensevar.get() == 'Preterito Imperfecto':
        if entry_3oslmn.get() == df_Preterito_Imperfecto['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Preterito_Imperfecto['ellos/ellas'][indexvar.get()]:
            entry_3oslmn.config(fg='red') 
                        
    elif tensevar.get() == 'Imperativo':
        if entry_3oslmn.get() == df_Imperativo['ustedes'][indexvar.get()]:
            entry_3oslmn.config(fg='green')
        elif entry_3oslmn.get() != df_Imperativo['ustedes'][indexvar.get()]:
            entry_3oslmn.config(fg='red')  
            
def verifyo7():
    
    if tensevar.get() == 'Gerundio':
        if entry_misc.get() == df_Gerundio['Forma'][indexvar.get()]:
            entry_misc.config(fg='green')
        elif entry_misc.get() != df_Gerundio['Forma'][indexvar.get()]:
            entry_misc.config(fg='red')
            
    elif tensevar.get() == 'Participio':
        if entry_misc.get() == df_Participio['Forma'][indexvar.get()]:
            entry_misc.config(fg='green')
        elif entry_misc.get() != df_Participio['Forma'][indexvar.get()]:
            entry_misc.config(fg='red')
    return()




def on_focus_in(event):
    global current_entry
    current_entry = event.widget # save the selected entry

def on_focus_out(event):
    global current_entry
    current_entry = None

def send_key(key):
    if current_entry:
        current_entry.insert('insert', key) # insert the key to the selected entry

# %%
##########APLIKACJA


#Glowne okienko
main_screen = Tk()
main_screen.title("Tlumaczonko")
main_screen.geometry("414x896")

current_entry = None # hold the reference to the selected entry


###Labelki

LabelCzasownik = Label(main_screen,text = "Czasownik:")
LabelCzasownik.place(x=207, y=120,anchor='center')
LabelCzasowniklos = Label(main_screen,text = '')
LabelCzasowniklos.place(x=207, y=150,anchor='center')
LabelCzasownikTlumaczenie = Label(main_screen,text = "Tlumaczenie:" )
LabelCzasownikTlumaczenie.place(x=207, y=185,anchor='center')
LabelCzasownikTlumaczenielos = Label(main_screen,text = '')
LabelCzasownikTlumaczenielos.place(x=207, y=215,anchor='center')
LabelCzas = Label(main_screen,text = "Czas:")
LabelCzas.place(x=207, y=250,anchor='center')
LabelCzaslos = Label(main_screen,text = '')
LabelCzaslos.place(x=207, y=280,anchor='center')


###Osoby

lbl_1oslpoj= Label(main_screen,
                   text = "yo").place(x=41, y=394)
lbl_2oslpoj = Label(main_screen,
                    text = "tú").place(x=41, y=444)
lbl_3oslpoj = Label(main_screen,
                    text = "él/ella/usted").place(x=41, y=494)
lbl_1oslmn = Label(main_screen,
                   text = "nosotros/as").place(x=41, y=544)
lbl_2oslmn = Label(main_screen,
                   text = "vosotros/as").place(x=41, y=594)
lbl_3oslmn = Label(main_screen,
                   text = "ellos/ellas/ustedes").place(x=41, y=644)
lbl_misc = Label(main_screen,
                 text = "Inne").place(x=41,y=694)

entry1var = StringVar()
entry2var = StringVar()
entry3var = StringVar()
entry4var = StringVar()
entry5var = StringVar()
entry6var = StringVar()
entry7var = StringVar()


###Inputboxy
entry_1oslpoj = Entry(main_screen,state='disabled',textvariable = entry1var)
entry_1oslpoj.place(x=210,y=404,anchor='center')
entry_1oslpoj.bind('<FocusIn>', on_focus_in)
entry_1oslpoj.bind('<FocusOut>', on_focus_out)

entry_2oslpoj = Entry(main_screen,state='disabled',textvariable = entry2var)
entry_2oslpoj.place(x=210,y=454,anchor='center')
entry_2oslpoj.bind('<FocusIn>', on_focus_in)
entry_2oslpoj.bind('<FocusOut>', on_focus_out)

entry_3oslpoj = Entry(main_screen,state='disabled',textvariable = entry3var)
entry_3oslpoj.place(x=210,y=504,anchor='center')
entry_3oslpoj.bind('<FocusIn>', on_focus_in)
entry_3oslpoj.bind('<FocusOut>', on_focus_out)

entry_1oslmn = Entry(main_screen,state='disabled',textvariable = entry4var)
entry_1oslmn.place(x=210,y=554,anchor='center')
entry_1oslmn.bind('<FocusIn>', on_focus_in)
entry_1oslmn.bind('<FocusOut>', on_focus_out)

entry_2oslmn = Entry(main_screen,state='disabled',textvariable = entry5var)
entry_2oslmn.place(x=210,y=604,anchor='center')
entry_2oslmn.bind('<FocusIn>', on_focus_in)
entry_2oslmn.bind('<FocusOut>', on_focus_out)

entry_3oslmn = Entry(main_screen,state='disabled',textvariable = entry6var)
entry_3oslmn.place(x=210,y=654,anchor='center')
entry_3oslmn.bind('<FocusIn>', on_focus_in)
entry_3oslmn.bind('<FocusOut>', on_focus_out)

entry_misc = Entry(main_screen,state='disabled',textvariable = entry7var)
entry_misc.place(x=210,y=704,anchor='center')
entry_misc.bind('<FocusIn>', on_focus_in)
entry_misc.bind('<FocusOut>', on_focus_out)


#######Otwieranie ekranu wyboru czasów
###Zmienne do checkboxow

Cbtn1 = IntVar()
Cbtn2 = IntVar()
Cbtn3 = IntVar()
Cbtn4 = IntVar()
Cbtn5 = IntVar()
Cbtn6 = IntVar()
Cbtn7 = IntVar()
Cbtn8 = IntVar()
Cbtn9 = IntVar()
Cbtn10 = IntVar()
Cbtn11 = IntVar()
ListVar = StringVar()


verbvar = StringVar()
tensevar = StringVar()
translatevar = StringVar()
indexvar = IntVar()

conj_1 = StringVar()
conj_2 = StringVar()
conj_3 = StringVar()
conj_4 = StringVar()
conj_5 = StringVar()
conj_6 = StringVar()
conj_7 = StringVar()

###Ekran wyboru czasow
def open_tense_screen():
    
    
    def get_tenses():
        Listavar = [Cbtn1.get(), Cbtn2.get(), Cbtn3.get(),
                    Cbtn4.get(), Cbtn5.get(),Cbtn6.get(),
                    Cbtn7.get(), Cbtn8.get(),Cbtn9.get(),
                    Cbtn10.get(), Cbtn11.get()]
        
        #Przepisanie wartosci
        Listavar1 = []
        for val in range(len(Listavar)):
            if Listavar[val] == 1:
                Listavar1.append(df_Tenses['Czasy'][val])
#             elif Listavar[val] == 0:            
#                 print("Błąd")
        ListVar.set(Listavar1)
        Tense_screen.destroy()
        
        
        
    Tense_screen = Toplevel(main_screen)
    Tense_screen.title("Wybór Czasów")
    Tense_screen.geometry("414x896")
    lbl_choose_tense= Label(Tense_screen, text = "Wybierz czas").place(x=68, y=26,anchor='center')
    Checkbutton1=Checkbutton(Tense_screen,text="Gerundio",variable = Cbtn1).place(x=58,y=56)
    Checkbutton2=Checkbutton(Tense_screen,text="Participio",variable = Cbtn2).place(x=58,y=86)
    Checkbutton3=Checkbutton(Tense_screen,text="Indicativo Presente",variable = Cbtn3).place(x=58,y=116)
    Checkbutton4=Checkbutton(Tense_screen,text="Indicativo Preterito Imperfecto",variable = Cbtn4).place(x=58,y=146)
    Checkbutton5=Checkbutton(Tense_screen,text="Indicativo Preterito Perfecto Simple",variable = Cbtn5).place(x=58,y=176)
    Checkbutton6=Checkbutton(Tense_screen,text="Indicativo Futuro Simple",variable = Cbtn6).place(x=58,y=206)
    Checkbutton7=Checkbutton(Tense_screen,text="Condicional Simple",variable = Cbtn7).place(x=58,y=236)
    Checkbutton8=Checkbutton(Tense_screen,text="Subjuntivo Presente",variable = Cbtn8).place(x=58,y=266)
    Checkbutton9=Checkbutton(Tense_screen,text="Subjuntivo Futuro Simple",variable = Cbtn9).place(x=58,y=296)
    Checkbutton10=Checkbutton(Tense_screen,text="Preterito Imperfecto",variable = Cbtn10).place(x=58,y=326)
    Checkbutton11=Checkbutton(Tense_screen,text="Imperativo",variable = Cbtn11).place(x=58,y=356)
    btn_close = Button(Tense_screen,text="Zapisz wybór",command = get_tenses).place(x=58,y=396)

    
def Suggestion():
    Suggestion_screen = Toplevel(main_screen)
    Suggestion_screen.title("Wskazówki")
    tensechoice = Convert(ListVar.get())
    
    if tensechoice[0] == "":
        Suggestion_screen.geometry("150x50")
        lbl_Suggestion= Label(Suggestion_screen, text = "Najpierw wybierz czas").place(x=75, y=25,anchor='center')
        
        
    elif tensechoice[0] != "":
        Suggestion_screen.geometry("300x450")
        
        lbl_1oslpoj= Label(Suggestion_screen,
                           text = "yo").place(x=30, y=34)
        lbl_2oslpoj = Label(Suggestion_screen,
                            text = "tú").place(x=30, y=84)
        lbl_3oslpoj = Label(Suggestion_screen,
                            text = "él/ella/usted").place(x=30, y=134)
        lbl_1oslmn = Label(Suggestion_screen,
                           text = "nosotros/as").place(x=30, y=184)
        lbl_2oslmn = Label(Suggestion_screen,
                           text = "vosotros/as").place(x=30, y=234)
        lbl_3oslmn = Label(Suggestion_screen,
                           text = "ellos/ellas/ustedes").place(x=30, y=284)
        lbl_misc = Label(Suggestion_screen,
                         text = "Inne").place(x=30,y=334)
    
        if tensevar.get() == "Indicativo Presente":
            conj_7.set("-")
            if verbvar.get()[-2:] == "ar":

                conj_1.set("-o")
                conj_2.set("-as")
                conj_3.set("-a")
                conj_4.set("-amos")
                conj_5.set("-áis")
                conj_6.set("-an")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)

            elif verbvar.get()[-2:] == "er":

                conj_1.set("-o")
                conj_2.set("-es")
                conj_3.set("-e")
                conj_4.set("-emos")
                conj_5.set("-éis")
                conj_6.set("-en")
              

                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)

            elif verbvar.get()[-2:] == "ir":

                conj_1.set("-o")
                conj_2.set("-es")
                conj_3.set("-e")
                conj_4.set("-imos")
                conj_5.set("-ís")
                conj_6.set("-en")
 


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)


        if tensevar.get() == "Indicativo Futuro Simple":    
            conj_7.set("-")
            if verbvar.get()[-2:] == "ar":


                conj_1.set("-é")
                conj_2.set("-ás")
                conj_3.set("-á")
                conj_4.set("-emos")
                conj_5.set("-éis")
                conj_6.set("-án")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":

                conj_1.set("-é")
                conj_2.set("-ás")
                conj_3.set("-á")
                conj_4.set("-emos")
                conj_5.set("-éis")
                conj_6.set("-án")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":

                conj_1.set("-é")
                conj_2.set("-ás")
                conj_3.set("-á")
                conj_4.set("-emos")
                conj_5.set("-éis")
                conj_6.set("-án")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)  
                
        if tensevar.get() == "Condicional Simple":    
            conj_7.set("-")
            if verbvar.get()[-2:] == "ar":


                conj_1.set("-ía")
                conj_2.set("-ías")
                conj_3.set("-ía")
                conj_4.set("-íamos")
                conj_5.set("-íais")
                conj_6.set("-ían")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":

                conj_1.set("-ía")
                conj_2.set("-ías")
                conj_3.set("-ía")
                conj_4.set("-íamos")
                conj_5.set("-íais")
                conj_6.set("-ían")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":

                conj_1.set("-ía")
                conj_2.set("-ías")
                conj_3.set("-ía")
                conj_4.set("-íamos")
                conj_5.set("-íais")
                conj_6.set("-ían")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)
    
        if tensevar.get() == "Indicativo Preterito Perfecto Simple":    
            conj_7.set("-")
            if verbvar.get()[-2:] == "ar":


                conj_1.set("-é")
                conj_2.set("-aste")
                conj_3.set("-ó")
                conj_4.set("-amos")
                conj_5.set("-isteis")
                conj_6.set("-aron")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":

                conj_1.set("-ía")
                conj_2.set("-iste")
                conj_3.set("-ió")
                conj_4.set("-imos")
                conj_5.set("-isteis")
                conj_6.set("-ieron")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":

                conj_1.set("-í")
                conj_2.set("-iste")
                conj_3.set("-ió")
                conj_4.set("-imos")
                conj_5.set("-isteis")
                conj_6.set("-ieron")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)    

                
        if tensevar.get() == "Indicativo Preterito Imperfecto":    
            conj_7.set("-")
            if verbvar.get()[-2:] == "ar":


                conj_1.set("-aba")
                conj_2.set("-abas")
                conj_3.set("-aba")
                conj_4.set("-abamos")
                conj_5.set("-abais")
                conj_6.set("-aban")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":

                conj_1.set("-ía")
                conj_2.set("-ías")
                conj_3.set("-ía")
                conj_4.set("-íamos")
                conj_5.set("-íais")
                conj_6.set("-ían")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":

                conj_1.set("-ía")
                conj_2.set("-ías")
                conj_3.set("-ía")
                conj_4.set("-íamos")
                conj_5.set("-íais")
                conj_6.set("-ían")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)

                
                
        if tensevar.get() == "Subjuntivo Presente":    
            conj_7.set("-")
            if verbvar.get()[-2:] == "ar":


                conj_1.set("-e")
                conj_2.set("-es")
                conj_3.set("-e")
                conj_4.set("-emos")
                conj_5.set("-éis")
                conj_6.set("-en")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":

                conj_1.set("-o")
                conj_2.set("-es")
                conj_3.set("-e")
                conj_4.set("-emos")
                conj_5.set("-éis")
                conj_6.set("-en")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":

                conj_1.set("-a")
                conj_2.set("-as")
                conj_3.set("-a")
                conj_4.set("-amos")
                conj_5.set("-áis")
                conj_6.set("-an")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)
                
                
        if tensevar.get() == "Subjuntivo Futuro Simple":    
            conj_7.set("-")
            if verbvar.get()[-2:] == "ar":


                conj_1.set("-are")
                conj_2.set("-ares")
                conj_3.set("-are")
                conj_4.set("-aremos")
                conj_5.set("-areis")
                conj_6.set("-aren")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":

                conj_1.set("-iere")
                conj_2.set("-ieres")
                conj_3.set("-iere")
                conj_4.set("-iéremos")
                conj_5.set("-iereis")
                conj_6.set("-ieren")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":

                conj_1.set("-iere")
                conj_2.set("-ieres")
                conj_3.set("-iere")
                conj_4.set("-iéremos")
                conj_5.set("-iereis")
                conj_6.set("-ieren")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)                
        if tensevar.get() == "Preterito Imperfecto":    
            conj_7.set("-")
            if verbvar.get()[-2:] == "ar":


                conj_1.set("-ara | -ase")
                conj_2.set("-aras | -ases")
                conj_3.set("-ara | -ase")
                conj_4.set("-áramos | -ásemos")
                conj_5.set("-arais | -aseis")
                conj_6.set("-aran | -asen")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":

                conj_1.set("-iera | -iese")
                conj_2.set("-ieras | -ieses")
                conj_3.set("-iera | -iese")
                conj_4.set("-iéramos | -iésemos")
                conj_5.set("-ierais | -ieseis")
                conj_6.set("-ieran | -iesen")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":

                conj_1.set("-iera | -iese")
                conj_2.set("-ieras | -ieses")
                conj_3.set("-iera | -iese")
                conj_4.set("-iéramos | -iésemos")
                conj_5.set("-ierais | -ieseis")
                conj_6.set("-ieran | -iesen")



                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)    
                
        if tensevar.get() == "Gerundio":    

            conj_1.set("-")
            conj_2.set("-")
            conj_3.set("-")
            conj_4.set("-")
            conj_5.set("-")
            conj_6.set("-")

            if verbvar.get()[-2:] == "ar":



                conj_7.set("-ando")

                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":


                conj_7.set("-iendo")

                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":


                conj_7.set("-iendo")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)
                
        if tensevar.get() == "Participio":    

            conj_1.set("-")
            conj_2.set("-")
            conj_3.set("-")
            conj_4.set("-")
            conj_5.set("-")
            conj_6.set("-")

            if verbvar.get()[-2:] == "ar":



                conj_7.set("-ado")

                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":


                conj_7.set("-ido")

                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":


                conj_7.set("-ido")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)
                
                
                
        if tensevar.get() == "Imperativo":    

            conj_1.set("-")
            conj_4.set("-")
            conj_7.set("-")

            if verbvar.get()[-2:] == "ar":
                conj_2.set("-a")
                conj_3.set("-e")
                conj_5.set("-ad")
                conj_6.set("-en")



                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)   


            elif verbvar.get()[-2:] == "er":
                conj_2.set("-e")
                conj_3.set("-a")
                conj_5.set("-ed")
                conj_6.set("-an")


                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)     


            elif verbvar.get()[-2:] == "ir":
                conj_2.set("-e")
                conj_3.set("-a")
                conj_5.set("-id")
                conj_6.set("-an")



                lbl_text_1oslpoj= Label(Suggestion_screen,
                                   textvariable = conj_1).place(x=175, y=34)
                lbl_text_2oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_2).place(x=175, y=84)
                lbl_text_3oslpoj = Label(Suggestion_screen,
                                    textvariable = conj_3).place(x=175, y=134)
                lbl_text_1oslmn = Label(Suggestion_screen,
                                   textvariable = conj_4).place(x=175, y=184)
                lbl_text_2oslmn = Label(Suggestion_screen,
                                   textvariable = conj_5).place(x=175, y=234)
                lbl_text_3oslmn = Label(Suggestion_screen,
                                   textvariable = conj_6).place(x=175, y=284)
                lbl_text_misc = Label(Suggestion_screen,
                                 textvariable = conj_7).place(x=175,y=334)
                

###Przyciski
Btn_losuj = Button(main_screen,
                   text="Losuj czasownik",command=losuj).place(x=207,y=60,anchor='center')
Btn_sprawdz = Button(main_screen,
                     text="Pokaż odpowiedzi",command = sprawdz).place(x=195,y=751,anchor='center')
Btn_wybor_czasow = Button(main_screen,
                          text="Wybor czasow", command=open_tense_screen).place(x=330,y=60,anchor='center')
Btn_o1 = Button(main_screen,
                text="O",command = verifyo1).place(x=290,y=404,anchor='center')
Btn_o2 = Button(main_screen,
                text="O",command = verifyo2).place(x=290,y=454,anchor='center')
Btn_o3 = Button(main_screen,
                text="O",command = verifyo3).place(x=290,y=504,anchor='center')
Btn_o4 = Button(main_screen,
                text="O",command = verifyo4).place(x=290,y=554,anchor='center')
Btn_o5 = Button(main_screen,
                text="O",command = verifyo5).place(x=290,y=604,anchor='center')
Btn_o6 = Button(main_screen,
                text="O",command = verifyo6).place(x=290,y=654,anchor='center')
Btn_o7 = Button(main_screen,
                text="O",command = verifyo7).place(x=290,y=704,anchor='center')  
Btn_v = Button(main_screen,
                text="W",command = lambda:[verifyo1(), verifyo2(),
                                           verifyo3(), verifyo4(),
                                           verifyo5(), verifyo6(),
                                           verifyo7()]).place(x=290,y=751,anchor='center') 
Btn_Suggestion = Button(main_screen,
                   text="Wskazówki",command=Suggestion).place(x=207,y=315,anchor='center')



btn_letter1 = Button(main_screen,text="á", command=lambda:send_key("á")).place(x=155,y=367,anchor='center')
btn_letter2 = Button(main_screen,text="é", command=lambda:send_key("é")).place(x=176,y=367,anchor='center')
btn_letter3 = Button(main_screen,text="í", command=lambda:send_key("í")).place(x=198,y=367,anchor='center')
btn_letter4 = Button(main_screen,text="ó", command=lambda:send_key("ó")).place(x=220,y=367,anchor='center')
btn_letter5 = Button(main_screen,text="ú", command=lambda:send_key("ú")).place(x=242,y=367,anchor='center')
btn_letter6 = Button(main_screen,text="ñ", command=lambda:send_key("ñ")).place(x=264,y=367,anchor='center')
    
# btn_tescik = Button(main_screen,text="Zapfsafsadfa",command = konwertujliste).place(x=58,y=766)

conj1 = StringVar()
conj2 = StringVar()
conj3 = StringVar()
conj4 = StringVar()
conj5 = StringVar()
conj6 = StringVar()
conj7 = StringVar()


#Odpalanie okna
main_screen.mainloop()

# %%
#     entry_1oslpoj.config(textvariable='')
#     entry_2oslpoj.config(textvariable='')
#     entry_3oslpoj.config(textvariable='')
#     entry_1oslmn.config(textvariable='')
#     entry_2oslmn.config(textvariable='')
#     entry_3oslmn.config(textvariable='')
#     entry_misc.config(textvariable='')
